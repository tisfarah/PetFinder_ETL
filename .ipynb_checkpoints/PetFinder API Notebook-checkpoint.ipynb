# %% [markdown]
# ### API Limits
# * Max 100 results per page, default is 20
# * Basic access is granted automatically after collecting a few details and will allow you to make up to 1,000 requests/day, with a rate limit of 50 requests/second. If you need more bandwidth, you can request more once you have your basic key.
# * Access tokens expire in 3600 seconds (1 hour)

# %% [markdown]
# ### Useful Links
# * https://curl.trillworks.com/
# * https://www.petfinder.com/developers/v2/docs/
# * https://github.com/aschleg/petpy
# * https://stackoverflow.com/questions/17777845/python-requests-arguments-dealing-with-api-pagination
# * https://petpy.readthedocs.io/en/latest/api.html
#
# #### Display images
#
# * https://pillow.readthedocs.io/en/stable/
# * https://stackoverflow.com/questions/11854847/how-can-i-display-an-image-from-a-file-in-jupyter-notebook
#
# #### Google Places API
# * https://developers.google.com/places/web-service/supported_types

# %% [markdown]
# # Connecting to PetFinder API

# %%
import requests
from config import CLIENTID
from config import CLIENTSECRET
import petpy as Petfinder
from datetime import datetime
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt 
from IPython.display import Image, display, Markdown
import json

credentials = {
  'grant_type': 'client_credentials',
  'client_id': {CLIENTID},
  'client_secret': {CLIENTSECRET}
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=credentials)
access_token = token_response.json()['access_token']

data_auth = {
    'Authorization': f'Bearer {access_token}',
}

# Example GET request 
# data_response = requests.get('https://api.petfinder.com/v2/{CATEGORY}/{ACTION}?{parameter_1}={value_1}', headers=data_auth)
startTime = datetime.now()

# time to check start of access token 
print(startTime)
# Out:
# 2019-05-14 20:34:39.596659

# %% [markdown]
# ## Pug Sample

# %%
# parameters = {animal_type:"dog" , breed: "pug", }
base_url = "https://api.petfinder.com/v2/animals?"
add_type = "&type="
add_breed = "&breed="
add_city = "&city="
end_url = "&page=1&limit=10"
target_url = base_url + add_type + "dog" + add_breed + "pug" + end_url
data_response = requests.get(target_url, headers=data_auth)
data_response.json() # this is a dictionary 

# convert nested json to dataframe

# %% [markdown]
# ## Filter for Dogs

# %%
# parameters = {animal_type:"dog" , breed: "pug", }
base_url = "https://api.petfinder.com/v2/animals?"
add_type = "&type="
add_breed = "&breed="
add_city = "&city="
end_url = "&page=1&limit=100"
target_url = base_url + add_type + "dog" + end_url
data_response = requests.get(target_url, headers=data_auth)
data_response.json() # this is a dictionary 

# convert nested json to dataframe
# Out:
# {'animals': [{'id': 44695085,
#    'organization_id': 'WA48',
#    'url': 'https://www.petfinder.com/dog/roscoe-44695085/wa/spokane/spokanimal-wa48/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Beagle',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Roscoe',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44695085/1/?bust=1557874348&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44695085/1/?bust=1557874348&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44695085/1/?bust=1557874348&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44695085/1/?bust=1557874348'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T22:52:38+0000',
#    'contact': {'email': 'miracles@spokanimal.org',
#     'phone': '(509) 534-8133',
#     'address': {'address1': '710 N Napa Street',
#      'address2': None,
#      'city': 'Spokane',
#      'state': 'WA',
#      'postcode': '99202',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44695085'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/wa48'}}},
#   {'id': 44694732,
#    'organization_id': 'OR50',
#    'url': 'https://www.petfinder.com/dog/toby-44694732/or/portland/oregon-humane-society-or50/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Toby',
#    'description': 'What my friends at OHS say about me:&amp;#10;&amp;#10;I&amp;#39;m a chill dude who is looking for that special someone, could it...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T21:13:16+0000',
#    'contact': {'email': 'survey@oregonhumane.org',
#     'phone': '503-285-7722  ',
#     'address': {'address1': '1067 NE Columbia Blvd',
#      'address2': None,
#      'city': 'Portland',
#      'state': 'OR',
#      'postcode': '97211',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44694732'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/or50'}}},
#   {'id': 44694360,
#    'organization_id': 'KY102',
#    'url': 'https://www.petfinder.com/dog/shemirra-44694360/ky/louisville/louisville-metro-animal-services-ky102/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Beagle',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'SHEMIRRA',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44694360/1/?bust=1557872817&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44694360/1/?bust=1557872817&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44694360/1/?bust=1557872817&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44694360/1/?bust=1557872817'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T20:59:06+0000',
#    'contact': {'email': 'AnimalServicesAdoption@louisvilleky.gov',
#     'phone': '(502) 473-7387',
#     'address': {'address1': '3516 Newburg Road Adoption Center',
#      'address2': '3705 Manslick Road Intake Facility',
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40218',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44694360'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ky102'}}},
#   {'id': 44694214,
#    'organization_id': 'TX424',
#    'url': 'https://www.petfinder.com/dog/a532840-44694214/tx/houston/harris-county-public-health-and-environmental-services-veterinary-public-health-tx424/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A532840',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T20:56:38+0000',
#    'contact': {'email': 'webmaster@countypets.com',
#     'phone': '(281) 999-3191',
#     'address': {'address1': '612 Canino Rd',
#      'address2': None,
#      'city': 'Houston',
#      'state': 'TX',
#      'postcode': '77076',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44694214'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx424'}}},
#   {'id': 44693873,
#    'organization_id': 'CA2366',
#    'url': 'https://www.petfinder.com/dog/addie-pug-44693873/ca/mission-viejo/leashes-of-love-rescue-inc-ca2366/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Dachshund',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': [],
#    'name': 'Addie Pug',
#    'description': 'Please welcome Addie to the Leashes of Love Crew! Addie is a 12 week old female Pug/ Wirehaired-Dachshund mix. Addie...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T20:43:54+0000',
#    'contact': {'email': 'lolrescue@outlook.com',
#     'phone': '949-445-5558',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Mission Viejo',
#      'state': 'CA',
#      'postcode': '92691',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44693873'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca2366'}}},
#   {'id': 44693814,
#    'organization_id': 'WA15',
#    'url': 'https://www.petfinder.com/dog/maxx-44693814/wa/bellingham/alternative-humane-society-of-whatcom-county-wa15/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pug',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': [],
#    'name': 'Maxx',
#    'description': 'This is Maxx. He is a senior we call them Frosty faces, he&#039;s very sweet he&#039;s still quite mobile will...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/1/?bust=1557879235&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/1/?bust=1557879235&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/1/?bust=1557879235&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/1/?bust=1557879235'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/2/?bust=1557879240&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/2/?bust=1557879240&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/2/?bust=1557879240&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/2/?bust=1557879240'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/3/?bust=1557879249&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/3/?bust=1557879249&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/3/?bust=1557879249&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44693814/3/?bust=1557879249'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T20:39:57+0000',
#    'contact': {'email': 'alternativehumanesociety@gmail.com',
#     'phone': '(360) 671-7445',
#     'address': {'address1': 'PO Box 2321',
#      'address2': None,
#      'city': 'Bellingham',
#      'state': 'WA',
#      'postcode': '98227',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44693814'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/wa15'}}},
#   {'id': 44692718,
#    'organization_id': 'CA2386',
#    'url': 'https://www.petfinder.com/dog/percy-44692718/ca/gardena/pug-nation-rescue-of-la-ca2386/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Percy',
#    'description': 'Before finding his way into our care, Percy was stuck in the Long Beach Shelter. We&#039;re not sure about the...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T19:54:32+0000',
#    'contact': {'email': 'gwenn@pugnationla.org',
#     'phone': '310-327-7871',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Gardena',
#      'state': 'CA',
#      'postcode': '90248',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44692718'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca2386'}}},
#   {'id': 44692719,
#    'organization_id': 'CA2386',
#    'url': 'https://www.petfinder.com/dog/george-44692719/ca/gardena/pug-nation-rescue-of-la-ca2386/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'George',
#    'description': 'George was brought to us by a concerned citizen who found him in a bad situation. This handsome boy is...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T19:54:32+0000',
#    'contact': {'email': 'gwenn@pugnationla.org',
#     'phone': '310-327-7871',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Gardena',
#      'state': 'CA',
#      'postcode': '90248',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44692719'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca2386'}}},
#   {'id': 44692253,
#    'organization_id': 'CA77',
#    'url': 'https://www.petfinder.com/dog/a054442-44692253/ca/upland/friends-of-upland-animal-shelter-ca77/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Chihuahua',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A054442',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44692253/1/?bust=1557871987&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44692253/1/?bust=1557871987&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44692253/1/?bust=1557871987&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44692253/1/?bust=1557871987'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T19:35:12+0000',
#    'contact': {'email': 'bseager@friendsofuplandanimalshelter.org',
#     'phone': '(909) 931-4185',
#     'address': {'address1': '1275 San Bernardino Road',
#      'address2': None,
#      'city': 'Upland',
#      'state': 'CA',
#      'postcode': '91786',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44692253'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca77'}}},
#   {'id': 44691899,
#    'organization_id': 'PA950',
#    'url': 'https://www.petfinder.com/dog/chester-44691899/pa/lewistown/one-dog-at-a-time-pa950/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Terrier',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Chester',
#    'description': 'You can fill out an adoption application online on our official website.',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/1/?bust=1557872469&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/1/?bust=1557872469&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/1/?bust=1557872469&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/1/?bust=1557872469'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/2/?bust=1557872472&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/2/?bust=1557872472&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/2/?bust=1557872472&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/2/?bust=1557872472'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/3/?bust=1557872474&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/3/?bust=1557872474&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/3/?bust=1557872474&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44691899/3/?bust=1557872474'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-14T19:25:01+0000',
#    'contact': {'email': 'adoptodaat@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Lewistown',
#      'state': 'PA',
#      'postcode': '17044',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44691899'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/pa950'}}}],
#  'pagination': {'count_per_page': 10,
#   'total_count': 70714,
#   'current_page': 1,
#   'total_pages': 7072,
#   '_links': {'next': {'href': '/v2/animals?breed=pug&limit=10&page=2&type=dog'}}}}

# %%
# parameters = {animal_type:"dog" , breed: "pug", }
base_url = "https://api.petfinder.com/v2/types?"
# add_type = "&type="
# add_breed = "&breed="
# add_city = "&city="
# end_url = "&page=1&limit=2"
# target_url = base_url + add_type + "dog" + add_breed + "pug" + end_url
data_response = requests.get(base_url, headers=data_auth)
data_response.json() # this is a dictionary 

# convert nested json to dataframe
# Out:
# {'types': [{'name': 'Dog',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#    'colors': ['Apricot / Beige',
#     'Bicolor',
#     'Black',
#     'Brindle',
#     'Brown / Chocolate',
#     'Golden',
#     'Gray / Blue / Silver',
#     'Harlequin',
#     'Merle (Blue)',
#     'Merle (Red)',
#     'Red / Chestnut / Orange',
#     'Sable',
#     'Tricolor (Brown, Black, & White)',
#     'White / Cream',
#     'Yellow / Tan / Blond / Fawn'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/dog'},
#     'breeds': {'href': '/v2/types/dog/breeds'}}},
#   {'name': 'Cat',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long'],
#    'colors': ['Black',
#     'Black & White / Tuxedo',
#     'Blue Cream',
#     'Blue Point',
#     'Brown / Chocolate',
#     'Buff & White',
#     'Buff / Tan / Fawn',
#     'Calico',
#     'Chocolate Point',
#     'Cream / Ivory',
#     'Cream Point',
#     'Dilute Calico',
#     'Dilute Tortoiseshell',
#     'Flame Point',
#     'Gray & White',
#     'Gray / Blue / Silver',
#     'Lilac Point',
#     'Orange & White',
#     'Orange / Red',
#     'Seal Point',
#     'Smoke',
#     'Tabby (Brown / Chocolate)',
#     'Tabby (Buff / Tan / Fawn)',
#     'Tabby (Gray / Blue / Silver)',
#     'Tabby (Leopard / Spotted)',
#     'Tabby (Orange / Red)',
#     'Tabby (Tiger Striped)',
#     'Torbie',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/cat'},
#     'breeds': {'href': '/v2/types/cat/breeds'}}},
#   {'name': 'Rabbit',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Cream',
#     'Lilac',
#     'Orange / Red',
#     'Sable',
#     'Silver Marten',
#     'Tan',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/rabbit'},
#     'breeds': {'href': '/v2/types/rabbit/breeds'}}},
#   {'name': 'Small & Furry',
#    'coats': ['Hairless', 'Short', 'Long'],
#    'colors': ['Agouti',
#     'Albino',
#     'Black',
#     'Black Sable',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Calico',
#     'Champagne',
#     'Cinnamon',
#     'Cream',
#     'Orange / Red',
#     'Sable',
#     'Tan',
#     'Tortoiseshell',
#     'White',
#     'White (Dark-Eyed)'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/small-furry'},
#     'breeds': {'href': '/v2/types/small-furry/breeds'}}},
#   {'name': 'Horse',
#    'coats': [],
#    'colors': ['Appaloosa',
#     'Bay',
#     'Bay Roan',
#     'Black',
#     'Blue Roan',
#     'Brown',
#     'Buckskin',
#     'Champagne',
#     'Chestnut / Sorrel',
#     'Cremello',
#     'Dapple Gray',
#     'Dun',
#     'Gray',
#     'Grullo',
#     'Liver',
#     'Paint',
#     'Palomino',
#     'Perlino',
#     'Piebald',
#     'Pinto',
#     'Red Roan',
#     'Silver Bay',
#     'Silver Buckskin',
#     'Silver Dapple',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/horse'},
#     'breeds': {'href': '/v2/types/horse/breeds'}}},
#   {'name': 'Bird',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Buff',
#     'Gray',
#     'Green',
#     'Olive',
#     'Orange',
#     'Pink',
#     'Purple / Violet',
#     'Red',
#     'Rust / Rufous',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/bird'},
#     'breeds': {'href': '/v2/types/bird/breeds'}}},
#   {'name': 'Scales, Fins & Other',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Gray',
#     'Green',
#     'Iridescent',
#     'Orange',
#     'Purple',
#     'Red',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/scales-fins-other'},
#     'breeds': {'href': '/v2/types/scales-fins-other/breeds'}}},
#   {'name': 'Barnyard',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Black & White',
#     'Brindle',
#     'Brown',
#     'Gray',
#     'Pink',
#     'Red',
#     'Roan',
#     'Spotted',
#     'Tan',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/barnyard'},
#     'breeds': {'href': '/v2/types/barnyard/breeds'}}}]}

# %% [markdown]
# ## PetFinder API Dog Breeds

# %%
dogbreed_url = "https://api.petfinder.com/v2/types/dog/breeds?"
dog_response = requests.get(dogbreed_url, headers=data_auth)
dogbreed_dict = dog_response.json()
dogbreed_dict
# Out:
# {'breeds': [{'name': 'Affenpinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Afghan Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Airedale Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Akbash', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Akita', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Alaskan Malamute', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Eskimo Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Hairless Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Staffordshire Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'American Water Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Anatolian Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Appenzell Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Cattle Dog / Blue Heeler',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Kelpie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Australian Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Basenji', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Basset Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Beagle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bearded Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Beauceron', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bedlington Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Laekenois',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Malinois',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Belgian Shepherd / Tervuren',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bernese Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bichon Frise', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black and Tan Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Mouth Cur', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Black Russian Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bloodhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Blue Lacy', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bluetick Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boerboel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bolognese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Border Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Border Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Borzoi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boston Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bouvier des Flandres',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boxer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Boykin Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Briard', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Brittany Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Brussels Griffon', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bull Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Bullmastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cairn Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Canaan Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cane Corso', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cardigan Welsh Corgi',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Carolina Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Catahoula Leopard Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cattle Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Caucasian Sheepdog / Caucasian Ovtcharka',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cavalier King Charles Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chesapeake Bay Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chihuahua', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinese Crested Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinese Foo Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chinook', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chocolate Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Chow Chow', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': "Cirneco dell'Etna", '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Clumber Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cockapoo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Cocker Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Corgi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Coton de Tulear', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Curly-Coated Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dachshund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dalmatian', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dandie Dinmont Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Doberman Pinscher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dogo Argentino', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dogue de Bordeaux', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Dutch Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Cocker Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Pointer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Springer Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'English Toy Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Entlebucher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Eskimo Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Feist', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Field Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Fila Brasileiro', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Finnish Lapphund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Finnish Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Flat-Coated Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Foxhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'French Bulldog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Galgo Spanish Greyhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Pinscher', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Shepherd Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Shorthaired Pointer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'German Wirehaired Pointer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Giant Schnauzer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Glen of Imaal Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Golden Retriever', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Gordon Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Great Dane', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Great Pyrenees', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Greater Swiss Mountain Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Greyhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hamiltonstovare', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Harrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Havanese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Hovawart', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Husky', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Ibizan Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Icelandic Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Illyrian Sheepdog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Water Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Irish Wolfhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Italian Greyhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Jack Russell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Japanese Chin', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Jindo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kai Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Karelian Bear Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Keeshond', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kerry Blue Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kishu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Klee Kai', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Komondor', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kuvasz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Kyi Leo', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lakeland Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lancashire Heeler', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Leonberger', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lhasa Apso', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Lowchen', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Maltese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Manchester Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Maremma Sheepdog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'McNab', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Pinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mixed Breed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Cur', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Munsterlander', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Neapolitan Mastiff',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'New Guinea Singing Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Newfoundland Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norfolk Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Buhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Elkhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Lundehund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwich Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Nova Scotia Duck Tolling Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Old English Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Otterhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Papillon', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Parson Russell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Patterdale Terrier / Fell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pekingese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pembroke Welsh Corgi',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Peruvian Inca Orchid',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Petit Basset Griffon Vendeen',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pharaoh Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pit Bull Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Plott Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pointer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Polish Lowland Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pomeranian', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Podengo',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Water Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Presa Canario', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pug', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Puli', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pumi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pyrenean Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rat Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Redbone Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Retriever', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rhodesian Ridgeback',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rottweiler', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rough Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saint Bernard', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saluki', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Samoyed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sarplaninac', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schipperke', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schnauzer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Deerhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sealyham Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shar-Pei', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sheep Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shetland Sheepdog / Sheltie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shiba Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shih Tzu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Siberian Husky', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Silky Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Skye Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sloughi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Fox Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'South Russian Ovtcharka',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spanish Water Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spinone Italiano', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Staffordshire Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sussex Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Swedish Vallhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Thai Ridgeback', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tosa Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Manchester Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Treeing Walker Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Vizsla', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Weimaraner', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Springer Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'West Highland White Terrier / Westie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wheaten Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Whippet', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'White German Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wire Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Pointing Griffon',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Xoloitzcuintli / Mexican Hairless',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yellow Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yorkshire Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}}]}

# %%
dogbreed_df = pd.DataFrame.from_dict(dogbreed_dict, orient='columns')
dogbreed_df2 = dogbreed_df['breeds']

PetFinder_DogBreeds = []
for item in dogbreed_df2:
    PetFinder_DogBreeds.append(item["name"])

# %%
PetFinder_DogBreeds
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akbash',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American Eskimo Dog',
#  'American Foxhound',
#  'American Hairless Terrier',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Anatolian Shepherd',
#  'Appenzell Mountain Dog',
#  'Australian Cattle Dog / Blue Heeler',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Terrier',
#  'Basenji',
#  'Basset Hound',
#  'Beagle',
#  'Bearded Collie',
#  'Beauceron',
#  'Bedlington Terrier',
#  'Belgian Shepherd / Laekenois',
#  'Belgian Shepherd / Malinois',
#  'Belgian Shepherd / Sheepdog',
#  'Belgian Shepherd / Tervuren',
#  'Bernese Mountain Dog',
#  'Bichon Frise',
#  'Black and Tan Coonhound',
#  'Black Labrador Retriever',
#  'Black Mouth Cur',
#  'Black Russian Terrier',
#  'Bloodhound',
#  'Blue Lacy',
#  'Bluetick Coonhound',
#  'Boerboel',
#  'Bolognese',
#  'Border Collie',
#  'Border Terrier',
#  'Borzoi',
#  'Boston Terrier',
#  'Bouvier des Flandres',
#  'Boxer',
#  'Boykin Spaniel',
#  'Briard',
#  'Brittany Spaniel',
#  'Brussels Griffon',
#  'Bull Terrier',
#  'Bullmastiff',
#  'Cairn Terrier',
#  'Canaan Dog',
#  'Cane Corso',
#  'Cardigan Welsh Corgi',
#  'Carolina Dog',
#  'Catahoula Leopard Dog',
#  'Cattle Dog',
#  'Caucasian Sheepdog / Caucasian Ovtcharka',
#  'Cavalier King Charles Spaniel',
#  'Chesapeake Bay Retriever',
#  'Chihuahua',
#  'Chinese Crested Dog',
#  'Chinese Foo Dog',
#  'Chinook',
#  'Chocolate Labrador Retriever',
#  'Chow Chow',
#  "Cirneco dell'Etna",
#  'Clumber Spaniel',
#  'Cockapoo',
#  'Cocker Spaniel',
#  'Collie',
#  'Coonhound',
#  'Corgi',
#  'Coton de Tulear',
#  'Curly-Coated Retriever',
#  'Dachshund',
#  'Dalmatian',
#  'Dandie Dinmont Terrier',
#  'Doberman Pinscher',
#  'Dogo Argentino',
#  'Dogue de Bordeaux',
#  'Dutch Shepherd',
#  'English Bulldog',
#  'English Cocker Spaniel',
#  'English Coonhound',
#  'English Foxhound',
#  'English Pointer',
#  'English Setter',
#  'English Shepherd',
#  'English Springer Spaniel',
#  'English Toy Spaniel',
#  'Entlebucher',
#  'Eskimo Dog',
#  'Feist',
#  'Field Spaniel',
#  'Fila Brasileiro',
#  'Finnish Lapphund',
#  'Finnish Spitz',
#  'Flat-Coated Retriever',
#  'Fox Terrier',
#  'Foxhound',
#  'French Bulldog',
#  'Galgo Spanish Greyhound',
#  'German Pinscher',
#  'German Shepherd Dog',
#  'German Shorthaired Pointer',
#  'German Spitz',
#  'German Wirehaired Pointer',
#  'Giant Schnauzer',
#  'Glen of Imaal Terrier',
#  'Golden Retriever',
#  'Gordon Setter',
#  'Great Dane',
#  'Great Pyrenees',
#  'Greater Swiss Mountain Dog',
#  'Greyhound',
#  'Hamiltonstovare',
#  'Harrier',
#  'Havanese',
#  'Hound',
#  'Hovawart',
#  'Husky',
#  'Ibizan Hound',
#  'Icelandic Sheepdog',
#  'Illyrian Sheepdog',
#  'Irish Setter',
#  'Irish Terrier',
#  'Irish Water Spaniel',
#  'Irish Wolfhound',
#  'Italian Greyhound',
#  'Jack Russell Terrier',
#  'Japanese Chin',
#  'Jindo',
#  'Kai Dog',
#  'Karelian Bear Dog',
#  'Keeshond',
#  'Kerry Blue Terrier',
#  'Kishu',
#  'Klee Kai',
#  'Komondor',
#  'Kuvasz',
#  'Kyi Leo',
#  'Labrador Retriever',
#  'Lakeland Terrier',
#  'Lancashire Heeler',
#  'Leonberger',
#  'Lhasa Apso',
#  'Lowchen',
#  'Maltese',
#  'Manchester Terrier',
#  'Maremma Sheepdog',
#  'Mastiff',
#  'McNab',
#  'Miniature Bull Terrier',
#  'Miniature Dachshund',
#  'Miniature Pinscher',
#  'Miniature Poodle',
#  'Miniature Schnauzer',
#  'Mixed Breed',
#  'Mountain Cur',
#  'Mountain Dog',
#  'Munsterlander',
#  'Neapolitan Mastiff',
#  'New Guinea Singing Dog',
#  'Newfoundland Dog',
#  'Norfolk Terrier',
#  'Norwegian Buhund',
#  'Norwegian Elkhound',
#  'Norwegian Lundehund',
#  'Norwich Terrier',
#  'Nova Scotia Duck Tolling Retriever',
#  'Old English Sheepdog',
#  'Otterhound',
#  'Papillon',
#  'Parson Russell Terrier',
#  'Patterdale Terrier / Fell Terrier',
#  'Pekingese',
#  'Pembroke Welsh Corgi',
#  'Peruvian Inca Orchid',
#  'Petit Basset Griffon Vendeen',
#  'Pharaoh Hound',
#  'Pit Bull Terrier',
#  'Plott Hound',
#  'Pointer',
#  'Polish Lowland Sheepdog',
#  'Pomeranian',
#  'Poodle',
#  'Portuguese Podengo',
#  'Portuguese Water Dog',
#  'Presa Canario',
#  'Pug',
#  'Puli',
#  'Pumi',
#  'Pyrenean Shepherd',
#  'Rat Terrier',
#  'Redbone Coonhound',
#  'Retriever',
#  'Rhodesian Ridgeback',
#  'Rottweiler',
#  'Rough Collie',
#  'Saint Bernard',
#  'Saluki',
#  'Samoyed',
#  'Sarplaninac',
#  'Schipperke',
#  'Schnauzer',
#  'Scottish Deerhound',
#  'Scottish Terrier',
#  'Sealyham Terrier',
#  'Setter',
#  'Shar-Pei',
#  'Sheep Dog',
#  'Shepherd',
#  'Shetland Sheepdog / Sheltie',
#  'Shiba Inu',
#  'Shih Tzu',
#  'Siberian Husky',
#  'Silky Terrier',
#  'Skye Terrier',
#  'Sloughi',
#  'Smooth Collie',
#  'Smooth Fox Terrier',
#  'South Russian Ovtcharka',
#  'Spaniel',
#  'Spanish Water Dog',
#  'Spinone Italiano',
#  'Spitz',
#  'Staffordshire Bull Terrier',
#  'Standard Poodle',
#  'Standard Schnauzer',
#  'Sussex Spaniel',
#  'Swedish Vallhund',
#  'Terrier',
#  'Thai Ridgeback',
#  'Tibetan Mastiff',
#  'Tibetan Spaniel',
#  'Tibetan Terrier',
#  'Tosa Inu',
#  'Toy Fox Terrier',
#  'Toy Manchester Terrier',
#  'Treeing Walker Coonhound',
#  'Vizsla',
#  'Weimaraner',
#  'Welsh Springer Spaniel',
#  'Welsh Terrier',
#  'West Highland White Terrier / Westie',
#  'Wheaten Terrier',
#  'Whippet',
#  'White German Shepherd',
#  'Wire Fox Terrier',
#  'Wirehaired Dachshund',
#  'Wirehaired Pointing Griffon',
#  'Wirehaired Terrier',
#  'Xoloitzcuintli / Mexican Hairless',
#  'Yellow Labrador Retriever',
#  'Yorkshire Terrier']
