# %% [markdown]
# ### API Limits
# * Max 100 results per page, default is 20
# * Basic access is granted automatically after collecting a few details and will allow you to make up to 1,000 requests/day, with a rate limit of 50 requests/second. If you need more bandwidth, you can request more once you have your basic key.
# * Access tokens expire in 3600 seconds (1 hour)

# %% [markdown]
# ### Useful Links
# * https://curl.trillworks.com/
# * https://www.petfinder.com/developers/v2/docs/
# * https://github.com/aschleg/petpy
# * https://stackoverflow.com/questions/17777845/python-requests-arguments-dealing-with-api-pagination
# * https://petpy.readthedocs.io/en/latest/api.html
#
# #### Display images
#
# * https://pillow.readthedocs.io/en/stable/
# * https://stackoverflow.com/questions/11854847/how-can-i-display-an-image-from-a-file-in-jupyter-notebook
#
# #### Google Places API
# * https://developers.google.com/places/web-service/supported_types

# %% [markdown]
# # Connecting to PetFinder API

# %%
import requests
from config import CLIENTID
from config import CLIENTSECRET
import petpy as Petfinder
from datetime import datetime
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt 
from IPython.display import Image, display, Markdown
import json

credentials = {
  'grant_type': 'client_credentials',
  'client_id': {CLIENTID},
  'client_secret': {CLIENTSECRET}
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=credentials)
access_token = token_response.json()['access_token']

data_auth = {
    'Authorization': f'Bearer {access_token}',
}

# Example GET request 
# data_response = requests.get('https://api.petfinder.com/v2/{CATEGORY}/{ACTION}?{parameter_1}={value_1}', headers=data_auth)
startTime = datetime.now()

# time to check start of access token 
print(startTime)
# Out:
# 2019-05-18 10:43:28.039479

# %% [markdown]
# ## Pug Sample

# %%
# parameters = {animal_type:"dog" , breed: "pug", }
base_url = "https://api.petfinder.com/v2/animals?"
add_type = "&type="
add_breed = "&breed="
add_city = "&city="
end_url = "&page=1&limit=10"
target_url = base_url + add_type + "dog" + add_breed + "pug" + end_url
data_response = requests.get(target_url, headers=data_auth)
data_response.json() # this is a dictionary 

# convert nested json to dataframe
# Out:
# {'animals': [{'id': 44730011,
#    'organization_id': 'MI65',
#    'url': 'https://www.petfinder.com/dog/amelia-44730011/mi/oxford/k-9-stray-rescue-league-mi65/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Amelia',
#    'description': 'Amelia is one of the sweetest little 12 pound girls you will ever meet.  She gets along with big dogs...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/1/?bust=1558189731&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/1/?bust=1558189731&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/1/?bust=1558189731&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/1/?bust=1558189731'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/2/?bust=1558189731&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/2/?bust=1558189731&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/2/?bust=1558189731&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/2/?bust=1558189731'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/3/?bust=1558189732&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/3/?bust=1558189732&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/3/?bust=1558189732&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730011/3/?bust=1558189732'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:23:08+0000',
#    'contact': {'email': 'k9strayrescue@yahoo.com',
#     'phone': '(248) 628-0435',
#     'address': {'address1': '2120 Metamora Road',
#      'address2': None,
#      'city': 'Oxford',
#      'state': 'MI',
#      'postcode': '48371',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44730011'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/mi65'}}},
#   {'id': 44729955,
#    'organization_id': 'VA707',
#    'url': 'https://www.petfinder.com/dog/hank-fka-scout-44729955/va/herndon/new-love-animal-rescue-va707/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Hank (fka Scout)',
#    'description': 'SCOUT (NOW HANK) IS ADOPTED!&amp;#10;&amp;#10;WHERE I STARTED:&amp;#10;Scout was an owner-surrender, who through no fault of his own was searching for...',
#    'photos': [],
#    'status': 'adopted',
#    'published_at': '2019-05-18T14:17:19+0000',
#    'contact': {'email': 'Adopt@NewLoveAnimalRescue.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Herndon',
#      'state': 'VA',
#      'postcode': '20172',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44729955'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/va707'}}},
#   {'id': 44729692,
#    'organization_id': 'AZ130',
#    'url': 'https://www.petfinder.com/dog/mary-jo-44729692/az/phoenix/arizona-animal-welfare-league-and-spca-az130/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Mary Jo',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:11:54+0000',
#    'contact': {'email': 'adoptions1@aawl.org',
#     'phone': '602-273-6852',
#     'address': {'address1': '25 N. 40th Street',
#      'address2': None,
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'postcode': '85034',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44729692'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/az130'}}},
#   {'id': 44729355,
#    'organization_id': 'CA1726',
#    'url': 'https://www.petfinder.com/dog/eden-44729355/ca/san-francisco/family-dog-rescue-ca1726/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Husky',
#     'secondary': 'Pug',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Eden',
#    'description': 'You can fill out an adoption application online on our official website.',
#    'photos': [],
#    'status': 'adopted',
#    'published_at': '2019-05-18T14:07:43+0000',
#    'contact': {'email': 'adopt@ilovefamilydog.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'San Francisco',
#      'state': 'CA',
#      'postcode': '94103',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44729355'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca1726'}}},
#   {'id': 44729139,
#    'organization_id': 'MA13',
#    'url': 'https://www.petfinder.com/dog/heaven-44729139/ma/boston/animal-rescue-league-of-boston-ma13/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pekingese',
#     'secondary': 'Pug',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'HEAVEN',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:04:05+0000',
#    'contact': {'email': 'Boston-adoption@arlboston.org',
#     'phone': '(617) 426-9170',
#     'address': {'address1': '10 Chandler Street',
#      'address2': None,
#      'city': 'Boston',
#      'state': 'MA',
#      'postcode': '02116',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44729139'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ma13'}}},
#   {'id': 44729090,
#    'organization_id': 'TN90',
#    'url': 'https://www.petfinder.com/dog/onyx-44729090/tn/greeneville/greeneville-greene-county-humane-society-tn90/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Pekingese',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Onyx',
#    'description': None,
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:02:16+0000',
#    'contact': {'email': None,
#     'phone': '(423) 639-4771',
#     'address': {'address1': '950 Hal Henard Rd',
#      'address2': None,
#      'city': 'Greeneville',
#      'state': 'TN',
#      'postcode': '37744',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44729090'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tn90'}}},
#   {'id': 44728437,
#    'organization_id': 'IL491',
#    'url': 'https://www.petfinder.com/dog/macy-adam-44728437/il/rockford/paws-humane-society-il491/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': 'Chihuahua',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': False},
#    'tags': [],
#    'name': 'Macy / Adam',
#    'description': 'Macy is a pug/chihuahua mix who came in as an owner relinquishment. She is a active, sweet dog.&amp;#10;We appreciate your...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T13:44:47+0000',
#    'contact': {'email': 'SAgolan9@aol.com',
#     'phone': '(815) 299-7297',
#     'address': {'address1': 'P.O. Box 7722',
#      'address2': None,
#      'city': 'Rockford',
#      'state': 'IL',
#      'postcode': '61126',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44728437'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/il491'}}},
#   {'id': 44728399,
#    'organization_id': 'OK64',
#    'url': 'https://www.petfinder.com/dog/mallon-44728399/ok/prague/ok-save-a-dog-ok64/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Mallon',
#    'description': 'PLEASE SCROLL ALL THE WAY DOWN FOR ANIMAL&amp;#10;&amp;#10;INFORMATION BEFORE E MAILING I will not answer questions in an email that...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T13:44:01+0000',
#    'contact': {'email': 'k9saver@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Prague',
#      'state': 'OK',
#      'postcode': '74864',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44728399'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ok64'}}},
#   {'id': 44728400,
#    'organization_id': 'OK64',
#    'url': 'https://www.petfinder.com/dog/pepper-44728400/ok/prague/ok-save-a-dog-ok64/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Pepper',
#    'description': 'PLEASE SCROLL ALL THE WAY DOWN FOR ANIMAL&amp;#10;&amp;#10;INFORMATION BEFORE E MAILING I will not answer questions in an email that...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T13:44:01+0000',
#    'contact': {'email': 'k9saver@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Prague',
#      'state': 'OK',
#      'postcode': '74864',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44728400'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ok64'}}},
#   {'id': 44728401,
#    'organization_id': 'OK64',
#    'url': 'https://www.petfinder.com/dog/trixie-44728401/ok/prague/ok-save-a-dog-ok64/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pug',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Trixie',
#    'description': 'PLEASE SCROLL ALL THE WAY DOWN FOR ANIMAL&amp;#10;&amp;#10;INFORMATION BEFORE E MAILING I will not answer questions in an email that...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T13:44:01+0000',
#    'contact': {'email': 'k9saver@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Prague',
#      'state': 'OK',
#      'postcode': '74864',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44728401'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ok64'}}}],
#  'pagination': {'count_per_page': 10,
#   'total_count': 70730,
#   'current_page': 1,
#   'total_pages': 7073,
#   '_links': {'next': {'href': '/v2/animals?breed=pug&limit=10&page=2&type=dog'}}}}

# %% [markdown]
# ## Filter for Dogs

# %%
# parameters = {animal_type:"dog" , breed: "pug", }
base_url = "https://api.petfinder.com/v2/animals?"
add_type = "&type="
add_breed = "&breed="
add_city = "&city="
end_url1 = "&page=1&limit=100"
end_url2 = "&page=2&limit=100"
end_url3 = "&page=3&limit=100"
end_url4 = "&page=4&limit=100"
end_url5 = "&page=5&limit=100"

target_url = base_url + add_type + "dog" + end_url
data_response = requests.get(target_url, headers=data_auth)
data_response.json() # this is a dictionary 

# convert nested json to dataframe
# Out:
# {'animals': [{'id': 44730279,
#    'organization_id': 'AZ531',
#    'url': 'https://www.petfinder.com/dog/violetta-44730279/az/phoenix/lulubelle-animal-rescue-az531/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': '
},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca2369'}}},
#   {'id': 44730218,
#    'organization_id': 'MD423',
#    'url': 'https://www.petfinder.com/dog/red-44730218/md/derwood/montgomery-county-animal-services-and-adoption-ctr-md423/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'American Foxhound',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Red / Chestnut / Orange',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': False, 'dogs': True, 'cats': None},
#    'tags': ['active', 'playful'],
#    'name': 'Red',
#    'description': 'Red is a young, energetic boy who was too much for his owners to handle! This young pup has lots...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730218/1/?bust=1558189619&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730218/1/?bust=1558189619&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730218/1/?bust=1558189619&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730218/1/?bust=1558189619'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:32:23+0000',
#    'contact': {'email': 'adoptmcasac@montgomerycountymd.gov',
#     'phone': None,
#     'address': {'address1': '7315 Muncaster Mill Rd.',
#      'address2': None,
#      'city': 'Derwood',
#      'state': 'MD',
#      'postcode': '20855',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44730218'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/md423'}}},
#   {'id': 44730250,
#    'organization_id': 'IA21',
#    'url': 'https://www.petfinder.com/dog/ben-44730250/ia/washington/paws-and-more-animal-shelter-ia21/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Ben',
#    'description': 'More information to follow since I&#039;m new to the shelter.\n\nPer the Center for Shelter dogs Match-Up Evaluation--- \nDog Name:...',
#    'photos': [],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:32:11+0000',
#    'contact': {'email': 'washingtonpawsandmore1978@gmail.com',
#     'phone': '319-653-6713',
#     'address': {'address1': '1004 1/2 West Madison St',
#      'address2': None,
#      'city': 'Washington',
#      'state': 'IA',
#      'postcode': '52353',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44730250'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ia21'}}},
#   {'id': 44730251,
#    'organization_id': 'NC675',
#    'url': 'https://www.petfinder.com/dog/simba-stanly-44730251/nc/apex/peak-lab-rescue-nc675/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Tricolor (Brown, Black, & White)',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': [],
#    'name': 'Simba Stanly',
#    'description': 'Hi\n\nI am Simba, 7-8 week old lab mix who came to Peak Lab with my 2 sisters.  You know...',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/1/?bust=1558189694&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/1/?bust=1558189694&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/1/?bust=1558189694&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/1/?bust=1558189694'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/2/?bust=1558189699&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/2/?bust=1558189699&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/2/?bust=1558189699&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/2/?bust=1558189699'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/3/?bust=1558189704&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/3/?bust=1558189704&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/3/?bust=1558189704&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/3/?bust=1558189704'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/4/?bust=1558189707&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/4/?bust=1558189707&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/4/?bust=1558189707&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/4/?bust=1558189707'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/5/?bust=1558189707&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/5/?bust=1558189707&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/5/?bust=1558189707&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730251/5/?bust=1558189707'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:32:04+0000',
#    'contact': {'email': 'info@peaklabrescue.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Apex',
#      'state': 'NC',
#      'postcode': '27502',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44730251'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/nc675'}}},
#   {'id': 44730007,
#    'organization_id': 'FL300',
#    'url': 'https://www.petfinder.com/dog/zelda-44730007/fl/key-largo/key-largo-animal-shelter-fl300/?referrer_id=7d8a5ef8-5c74-4b22-b1c8-96ecb72018d7',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Doberman Pinscher',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Zelda',
#    'description': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/1/?bust=1558189298&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/1/?bust=1558189298&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/1/?bust=1558189298&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/1/?bust=1558189298'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/3/?bust=1558189506&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/3/?bust=1558189506&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/3/?bust=1558189506&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/3/?bust=1558189506'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/2/?bust=1558189657&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/2/?bust=1558189657&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/2/?bust=1558189657&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/44730007/2/?bust=1558189657'}],
#    'status': 'adoptable',
#    'published_at': '2019-05-18T14:28:29+0000',
#    'contact': {'email': 'tfgarr@aol.com',
#     'phone': '305-451-0088',
#     'address': {'address1': '105951 Overseas Highway',
#      'address2': 'MM106 OS',
#      'city': 'Key Largo',
#      'state': 'FL',
#      'postcode': '33037',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/44730007'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl300'}}}],
#  'pagination': {'count_per_page': 10,
#   'total_count': 4954865,
#   'current_page': 1,
#   'total_pages': 495487,
#   '_links': {'next': {'href': '/v2/animals?limit=10&page=2&type=dog'}}}}

# %% [markdown]
# ## PetFinder API Dog Breeds

# %%
base_url = "https://api.petfinder.com/v2/types?"
data_response = requests.get(base_url, headers=data_auth)
data_response.json() # this is a dictionary
# Out:
# {'types': [{'name': 'Dog',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#    'colors': ['Apricot / Beige',
#     'Bicolor',
#     'Black',
#     'Brindle',
#     'Brown / Chocolate',
#     'Golden',
#     'Gray / Blue / Silver',
#     'Harlequin',
#     'Merle (Blue)',
#     'Merle (Red)',
#     'Red / Chestnut / Orange',
#     'Sable',
#     'Tricolor (Brown, Black, & White)',
#     'White / Cream',
#     'Yellow / Tan / Blond / Fawn'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/dog'},
#     'breeds': {'href': '/v2/types/dog/breeds'}}},
#   {'name': 'Cat',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long'],
#    'colors': ['Black',
#     'Black & White / Tuxedo',
#     'Blue Cream',
#     'Blue Point',
#     'Brown / Chocolate',
#     'Buff & White',
#     'Buff / Tan / Fawn',
#     'Calico',
#     'Chocolate Point',
#     'Cream / Ivory',
#     'Cream Point',
#     'Dilute Calico',
#     'Dilute Tortoiseshell',
#     'Flame Point',
#     'Gray & White',
#     'Gray / Blue / Silver',
#     'Lilac Point',
#     'Orange & White',
#     'Orange / Red',
#     'Seal Point',
#     'Smoke',
#     'Tabby (Brown / Chocolate)',
#     'Tabby (Buff / Tan / Fawn)',
#     'Tabby (Gray / Blue / Silver)',
#     'Tabby (Leopard / Spotted)',
#     'Tabby (Orange / Red)',
#     'Tabby (Tiger Striped)',
#     'Torbie',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/cat'},
#     'breeds': {'href': '/v2/types/cat/breeds'}}},
#   {'name': 'Rabbit',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Cream',
#     'Lilac',
#     'Orange / Red',
#     'Sable',
#     'Silver Marten',
#     'Tan',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/rabbit'},
#     'breeds': {'href': '/v2/types/rabbit/breeds'}}},
#   {'name': 'Small & Furry',
#    'coats': ['Hairless', 'Short', 'Long'],
#    'colors': ['Agouti',
#     'Albino',
#     'Black',
#     'Black Sable',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Calico',
#     'Champagne',
#     'Cinnamon',
#     'Cream',
#     'Orange / Red',
#     'Sable',
#     'Tan',
#     'Tortoiseshell',
#     'White',
#     'White (Dark-Eyed)'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/small-furry'},
#     'breeds': {'href': '/v2/types/small-furry/breeds'}}},
#   {'name': 'Horse',
#    'coats': [],
#    'colors': ['Appaloosa',
#     'Bay',
#     'Bay Roan',
#     'Black',
#     'Blue Roan',
#     'Brown',
#     'Buckskin',
#     'Champagne',
#     'Chestnut / Sorrel',
#     'Cremello',
#     'Dapple Gray',
#     'Dun',
#     'Gray',
#     'Grullo',
#     'Liver',
#     'Paint',
#     'Palomino',
#     'Perlino',
#     'Piebald',
#     'Pinto',
#     'Red Roan',
#     'Silver Bay',
#     'Silver Buckskin',
#     'Silver Dapple',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/horse'},
#     'breeds': {'href': '/v2/types/horse/breeds'}}},
#   {'name': 'Bird',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Buff',
#     'Gray',
#     'Green',
#     'Olive',
#     'Orange',
#     'Pink',
#     'Purple / Violet',
#     'Red',
#     'Rust / Rufous',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/bird'},
#     'breeds': {'href': '/v2/types/bird/breeds'}}},
#   {'name': 'Scales, Fins & Other',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Gray',
#     'Green',
#     'Iridescent',
#     'Orange',
#     'Purple',
#     'Red',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/scales-fins-other'},
#     'breeds': {'href': '/v2/types/scales-fins-other/breeds'}}},
#   {'name': 'Barnyard',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Black & White',
#     'Brindle',
#     'Brown',
#     'Gray',
#     'Pink',
#     'Red',
#     'Roan',
#     'Spotted',
#     'Tan',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/barnyard'},
#     'breeds': {'href': '/v2/types/barnyard/breeds'}}}]}

# %%
dogbreed_url = "https://api.petfinder.com/v2/types/dog/breeds?"
dog_response = requests.get(dogbreed_url, headers=data_auth)
dogbreed_dict = dog_response.json()
dogbreed_dict
# Out:
# {'breeds': [{'name': 'Affenpinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': '
terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Maremma Sheepdog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'McNab', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Pinscher',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Miniature Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mixed Breed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Cur', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Mountain Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Munsterlander', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Neapolitan Mastiff',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'New Guinea Singing Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Newfoundland Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norfolk Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Buhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Elkhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwegian Lundehund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Norwich Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Nova Scotia Duck Tolling Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Old English Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Otterhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Papillon', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Parson Russell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Patterdale Terrier / Fell Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pekingese', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pembroke Welsh Corgi',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Peruvian Inca Orchid',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Petit Basset Griffon Vendeen',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pharaoh Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pit Bull Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Plott Hound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pointer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Polish Lowland Sheepdog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pomeranian', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Podengo',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Portuguese Water Dog',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Presa Canario', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pug', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Puli', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pumi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Pyrenean Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rat Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Redbone Coonhound', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Retriever', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rhodesian Ridgeback',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rottweiler', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Rough Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saint Bernard', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Saluki', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Samoyed', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sarplaninac', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schipperke', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Schnauzer', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Deerhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Scottish Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sealyham Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Setter', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shar-Pei', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sheep Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shepherd', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shetland Sheepdog / Sheltie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shiba Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Shih Tzu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Siberian Husky', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Silky Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Skye Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sloughi', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Collie', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Smooth Fox Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'South Russian Ovtcharka',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spanish Water Dog', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spinone Italiano', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Spitz', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Staffordshire Bull Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Poodle', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Standard Schnauzer',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Sussex Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Swedish Vallhund', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Thai Ridgeback', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Mastiff', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Spaniel', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tibetan Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Tosa Inu', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Toy Manchester Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Treeing Walker Coonhound',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Vizsla', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Weimaraner', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Springer Spaniel',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Welsh Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'West Highland White Terrier / Westie',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wheaten Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Whippet', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'White German Shepherd',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wire Fox Terrier', '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Dachshund',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Pointing Griffon',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Wirehaired Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Xoloitzcuintli / Mexican Hairless',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yellow Labrador Retriever',
#    '_links': {'type': {'href': '/v2/types/dog'}}},
#   {'name': 'Yorkshire Terrier',
#    '_links': {'type': {'href': '/v2/types/dog'}}}]}

# %%
dogbreed_df = pd.DataFrame.from_dict(dogbreed_dict, orient='columns')
dogbreed_df2 = dogbreed_df['breeds']

PetFinder_DogBreeds = []
for item in dogbreed_df2:
    PetFinder_DogBreeds.append(item["name"])

# %%
PetFinder_DogBreeds
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akbash',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American Eskimo Dog',
#  'American Foxhound',
#  'American Hairless Terrier',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Anatolian Shepherd',
#  'Appenzell Mountain Dog',
#  'Australian Cattle Dog / Blue Heeler',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Terrier',
#  'Basenji',
#  'Basset Hound',
#  'Beagle',
#  'Bearded Collie',
#  'Beauceron',
#  'Bedlington Terrier',
#  'Belgian Shepherd / Laekenois',
#  'Belgian Shepherd / Malinois',
#  'Belgian Shepherd / Sheepdog',
#  'Belgian Shepherd / Tervuren',
#  'Bernese Mountain Dog',
#  'Bichon Frise',
#  'Black and Tan Coonhound',
#  'Black Labrador Retriever',
#  'Black Mouth Cur',
#  'Black Russian Terrier',
#  'Bloodhound',
#  'Blue Lacy',
#  'Bluetick Coonhound',
#  'Boerboel',
#  'Bolognese',
#  'Border Collie',
#  'Border Terrier',
#  'Borzoi',
#  'Boston Terrier',
#  'Bouvier des Flandres',
#  'Boxer',
#  'Boykin Spaniel',
#  'Briard',
#  'Brittany Spaniel',
#  'Brussels Griffon',
#  'Bull Terrier',
#  'Bullmastiff',
#  'Cairn Terrier',
#  'Canaan Dog',
#  'Cane Corso',
#  'Cardigan Welsh Corgi',
#  'Carolina Dog',
#  'Catahoula Leopard Dog',
#  'Cattle Dog',
#  'Caucasian Sheepdog / Caucasian Ovtcharka',
#  'Cavalier King Charles Spaniel',
#  'Chesapeake Bay Retriever',
#  'Chihuahua',
#  'Chinese Crested Dog',
#  'Chinese Foo Dog',
#  'Chinook',
#  'Chocolate Labrador Retriever',
#  'Chow Chow',
#  "Cirneco dell'Etna",
#  'Clumber Spaniel',
#  'Cockapoo',
#  'Cocker Spaniel',
#  'Collie',
#  'Coonhound',
#  'Corgi',
#  'Coton de Tulear',
#  'Curly-Coated Retriever',
#  'Dachshund',
#  'Dalmatian',
#  'Dandie Dinmont Terrier',
#  'Doberman Pinscher',
#  'Dogo Argentino',
#  'Dogue de Bordeaux',
#  'Dutch Shepherd',
#  'English Bulldog',
#  'English Cocker Spaniel',
#  'English Coonhound',
#  'English Foxhound',
#  'English Pointer',
#  'English Setter',
#  'English Shepherd',
#  'English Springer Spaniel',
#  'English Toy Spaniel',
#  'Entlebucher',
#  'Eskimo Dog',
#  'Feist',
#  'Field Spaniel',
#  'Fila Brasileiro',
#  'Finnish Lapphund',
#  'Finnish Spitz',
#  'Flat-Coated Retriever',
#  'Fox Terrier',
#  'Foxhound',
#  'French Bulldog',
#  'Galgo Spanish Greyhound',
#  'German Pinscher',
#  'German Shepherd Dog',
#  'German Shorthaired Pointer',
#  'German Spitz',
#  'German Wirehaired Pointer',
#  'Giant Schnauzer',
#  'Glen of Imaal Terrier',
#  'Golden Retriever',
#  'Gordon Setter',
#  'Great Dane',
#  'Great Pyrenees',
#  'Greater Swiss Mountain Dog',
#  'Greyhound',
#  'Hamiltonstovare',
#  'Harrier',
#  'Havanese',
#  'Hound',
#  'Hovawart',
#  'Husky',
#  'Ibizan Hound',
#  'Icelandic Sheepdog',
#  'Illyrian Sheepdog',
#  'Irish Setter',
#  'Irish Terrier',
#  'Irish Water Spaniel',
#  'Irish Wolfhound',
#  'Italian Greyhound',
#  'Jack Russell Terrier',
#  'Japanese Chin',
#  'Jindo',
#  'Kai Dog',
#  'Karelian Bear Dog',
#  'Keeshond',
#  'Kerry Blue Terrier',
#  'Kishu',
#  'Klee Kai',
#  'Komondor',
#  'Kuvasz',
#  'Kyi Leo',
#  'Labrador Retriever',
#  'Lakeland Terrier',
#  'Lancashire Heeler',
#  'Leonberger',
#  'Lhasa Apso',
#  'Lowchen',
#  'Maltese',
#  'Manchester Terrier',
#  'Maremma Sheepdog',
#  'Mastiff',
#  'McNab',
#  'Miniature Bull Terrier',
#  'Miniature Dachshund',
#  'Miniature Pinscher',
#  'Miniature Poodle',
#  'Miniature Schnauzer',
#  'Mixed Breed',
#  'Mountain Cur',
#  'Mountain Dog',
#  'Munsterlander',
#  'Neapolitan Mastiff',
#  'New Guinea Singing Dog',
#  'Newfoundland Dog',
#  'Norfolk Terrier',
#  'Norwegian Buhund',
#  'Norwegian Elkhound',
#  'Norwegian Lundehund',
#  'Norwich Terrier',
#  'Nova Scotia Duck Tolling Retriever',
#  'Old English Sheepdog',
#  'Otterhound',
#  'Papillon',
#  'Parson Russell Terrier',
#  'Patterdale Terrier / Fell Terrier',
#  'Pekingese',
#  'Pembroke Welsh Corgi',
#  'Peruvian Inca Orchid',
#  'Petit Basset Griffon Vendeen',
#  'Pharaoh Hound',
#  'Pit Bull Terrier',
#  'Plott Hound',
#  'Pointer',
#  'Polish Lowland Sheepdog',
#  'Pomeranian',
#  'Poodle',
#  'Portuguese Podengo',
#  'Portuguese Water Dog',
#  'Presa Canario',
#  'Pug',
#  'Puli',
#  'Pumi',
#  'Pyrenean Shepherd',
#  'Rat Terrier',
#  'Redbone Coonhound',
#  'Retriever',
#  'Rhodesian Ridgeback',
#  'Rottweiler',
#  'Rough Collie',
#  'Saint Bernard',
#  'Saluki',
#  'Samoyed',
#  'Sarplaninac',
#  'Schipperke',
#  'Schnauzer',
#  'Scottish Deerhound',
#  'Scottish Terrier',
#  'Sealyham Terrier',
#  'Setter',
#  'Shar-Pei',
#  'Sheep Dog',
#  'Shepherd',
#  'Shetland Sheepdog / Sheltie',
#  'Shiba Inu',
#  'Shih Tzu',
#  'Siberian Husky',
#  'Silky Terrier',
#  'Skye Terrier',
#  'Sloughi',
#  'Smooth Collie',
#  'Smooth Fox Terrier',
#  'South Russian Ovtcharka',
#  'Spaniel',
#  'Spanish Water Dog',
#  'Spinone Italiano',
#  'Spitz',
#  'Staffordshire Bull Terrier',
#  'Standard Poodle',
#  'Standard Schnauzer',
#  'Sussex Spaniel',
#  'Swedish Vallhund',
#  'Terrier',
#  'Thai Ridgeback',
#  'Tibetan Mastiff',
#  'Tibetan Spaniel',
#  'Tibetan Terrier',
#  'Tosa Inu',
#  'Toy Fox Terrier',
#  'Toy Manchester Terrier',
#  'Treeing Walker Coonhound',
#  'Vizsla',
#  'Weimaraner',
#  'Welsh Springer Spaniel',
#  'Welsh Terrier',
#  'West Highland White Terrier / Westie',
#  'Wheaten Terrier',
#  'Whippet',
#  'White German Shepherd',
#  'Wire Fox Terrier',
#  'Wirehaired Dachshund',
#  'Wirehaired Pointing Griffon',
#  'Wirehaired Terrier',
#  'Xoloitzcuintli / Mexican Hairless',
#  'Yellow Labrador Retriever',
#  'Yorkshire Terrier']
